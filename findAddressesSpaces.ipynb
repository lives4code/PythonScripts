# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd
import os
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

path = "/home/jacob/Documents/College/seniorProject"
filename = 'snapshotSpaces.csv'
url = "https://etherscan.io/enslookup-search?search="



session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)
os.chdir(path)

df = pd.read_csv(filename)
def getAddressIfExist(name):
    address = url + name
    print(address)
    page = session.get(address, verify=False)

    #page = session.get(address)
    soup = BeautifulSoup(page.content, 'html.parser')
    print(soup.prettify())





#print(df)
notFound = df[df['address'] == 'not found']
#print(notFound['id'])
#print(df.loc['not found'])
print(notFound.loc[1]['id'])
name = notFound.loc[1]['id']
#print(df.at['id' == name, 'address'])
#print(df.loc['id' == name])
print(df.at[1, 'address'])

print("testing soup")
getAddressIfExist("bonustrack.eth")
# Out:
# fabien.eth
# not found
# testing soup
# https://etherscan.io/enslookup-search?search=bonustrack.eth
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Attention Required! | Cloudflare
#   </title>
#   <meta id="captcha-bypass" name="captcha-bypass"/>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="noindex, nofollow" name="robots"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/cdn-cgi/styles/cf.errors.css" id="cf_styles-css" media="screen,projection" rel="stylesheet" type="text/css"/>
# ...
